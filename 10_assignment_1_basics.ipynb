# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here
name= input("Enter your name ")
age = int(input("Enter your age "))


print(name)
print(age)
# Out:
# Dev Tiiwari
# 22

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here

num= int(input("Enter any digit"))

if num>0:
    print(num,"is positive")
elif num<0:
    print(num,"is negative")
else:
    print(num,"is zero")
# Out:
# 0 is zero

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here
a =int(input("Enter first digit"))
b =int(input("Enter second digit"))
c =int(input("Enter third digit"))

if a>=b and a>=c:
    print(a, "is greatest")
elif b>=a and b>=c:
    print(b,"is greatest")
else:
    print(c,"is greatest")
# Out:
# -2 is greatest

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here
a=int(input("Enter any digit"))
fact=1
 
for i in range (1,a+1):
    fact = fact*i
print("Factorial of",a,"is",fact )
# Out:
# Factorial of 10 is 3628800

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here
a= 33
b = 34.4
c ="dev"
d = True 
print(a)
print(b)
print(c)
print(d)
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# 33
# 34.4
# dev
# True
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# Your code here
a = 3 
b = 4
c = 0
print("a before swaping is ", a)
print("b before swaping is ", b)
c = a
a = b
b = c
print("a after swaping is ", a)
print("b after swaping is ", b)
# Out:
# a before swaping is  3
# b before swaping is  4
# a after swaping is  4
# b after swaping is  3

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here
c= int(input("Input the temp in celsius"))
fahren =( c *(9/5))+32
print("Temperature in fahrenheit is ", fahren)
# Out:
# Temperature in fahrenheit is  149.0

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here
a = "Dev "
b ="Tiwari"
c = a+b
print( "Concatenate string is ",c)
# Out:
# Concatenate string is  Dev Tiwari

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here
a = 2 
if isinstance (a,int):
    print(a, "is intiger" )
else :
    print(a,"is not an intiger ")
# Out:
# 2 is intiger

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here
a= int(input("Enter any digit"))
b= int(input("Enter any digit"))
print ("Addition of a  and b is ", a+b)
print ("subtration of a and b is ", a-b)
print ("Multiplction of a and b is ", a*b)
if b !=0:
    print ("Dividion of a and b is ", a/b)
else :
    print("Devision is not possible")
# Out:
# Addition of a  and b is  11
# subtration of a and b is  -1
# Multiplction of a and b is  30
# Dividion of a and b is  0.8333333333333334

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
a = 44
b = 55

print(a ==b)
print(a!=b)
print(a>b)
print(a<b)
# Out:
# False
# True
# False
# True

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here
a = True
b = False 
print (a and b)
print (a or b )
print (not a)
# Out:
# False
# True
# False

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here
a = int(input("Enter any digit"))
square = a*a
print("Square of ",a ,"is", square)
# Out:
# Square of  4 is 16

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here
num =int(input("Enter any digit"))
if num!=0:
    if num%2==0:
        print(num, "is even")
    else :
        print(num,"is odd")
else :
    print(num,"is zero")
# Out:
# 0 is zero

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here
a = int(input("Enter any digit"))
sum = 0
for i in range (a +1):
    sum =sum + i 
print (sum )
# Out:
# 5050

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here
a =int(input("Enter a year "))
if (a%4==0 and a%100!=0)or a%400==0:
    print (a , "is a leap year ")
else:
    print (a , "is not a leap year ")

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here
a = "dev tiwari"

print(a[::-1])
# Out:
# irawit ved

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here
a = "1221"
rev = a[::-1]
if a ==rev:
    print(a, "is palindrone")
else:
     print(a, "is not a palindrone")
# Out:
# 1221 is palindrone

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here
a = 1221
rev = a[::-1]
if a ==rev:
    print(a, "is palindrone")
else:
     print(a, "is not a palindrone")
# Out:
# Chal gaya 🔥
