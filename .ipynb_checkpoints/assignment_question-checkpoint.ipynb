# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("Hello world")

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here
new_input=input("Enter any value:")
print(new_input)

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here
a = int(input("Enter a number: "))
if a>0:
    print("Positive")
elif a<0:
    print("Negative")
else:
    print("Zero")

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here

a = int(input("Enter any number:"))
b = int(input("Enter second number :"))
c = int (input("Enter third number :"))

if (a>b and a>c):
    print("The largest number is:", a)
elif (b>a and b>c):
    print("The largest number is :" ,b)
else:
    print("The largest number is :" , c)

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here
num = int(input("Enter any number or digit: "))
fact = 1
while num>0:
    fact = fact * num 
    num = num -1
print("Factorial is:", fact)

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here
a = 1.1
print(a)
b = "dev"
print(b)
d = None
print(d)
f= 3443
print(a+f)
print (type(a))
print (type(b))
print (type(d))
print (type(f))

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# Your code here
a = 2
b = 5
print ("Before swapping a =",a,"and  b =",b)
c = a
a = b
b = c   
print ("After swapping a =",a ,"and b =",b)

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here
temprature_celsius = float(input("Enter the temprature in celsius :"))

temprature_fahrenheit = (temprature_celsius * 1.8) +32
print("The temprature in fahrenheit is :", temprature_fahrenheit)

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here
phrase1=input("Enter any word ")
phrase2= input("Enter second word ")
new_phrase = phrase1 + " "+ phrase2
print("The concatenated phrase is :", new_phrase)
# Out:
# Running cells with '.venv (3.14.3) (Python 3.14.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/devtiwari/Desktop/Mission_2026/.venv/bin/python -m pip install ipykernel -U --force-reinstall'

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here
a = 99.0
if isinstance(a, int):
    print(a," is an integer")
elif isinstance(a, float):
    print(a," is a float")
elif isinstance(a, str):
    print(a," is a string")
else:
    print(a," is of unknown type")

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here
print(15+6)
print(15-6)
print(15/6)
print(15*6)
print(15//6)#for printing values after point(.)
print(15%6)#for remainder
print(15**6)#it means 15 to the power of 6

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
a = int(input("Enter any value "))
b = int(input("Enter second value "))

c = a>b
d = a<b
e= a==b
f= a!=b
print("a>b",c)
print("a<b",d)
print("a==b",e)
print("a!=b",f)

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here
# Solution
a = True
b = False

print(f"True and False: {a and b}")
print(f"True or False: {a or b}")
print(f"not True: {not a}")

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here
a= int(input("Enter any value"))
sq= a*a
print("Square of the ", a, "is ",sq)

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here
a = int(input("enter any number"))
if a%2 == 0:
    print("Number",a,"  is even")
else:
    print("Number",a,"is odd")

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here
n = int(input("Enter any number"))
sum = 0
for x in range( n+1):
    sum = sum + x
print ("Sum of first ", n, "natural number is  ", sum)

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here
year=int(input("Enter any year :"))
if (year%4 == 0 and year%100 != 0) or (year%400 ==0):
    print(year," is a leap year")
else:
    print(year," is not a leap year")

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here
import sys
print(sys.executable)

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here
print("Chal gaya 🔥")
